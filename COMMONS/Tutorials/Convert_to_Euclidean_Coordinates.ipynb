# %%
# Import relevant libraries 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# Print Working Directory - gives you the folder/directory you are currently "in" while using this notebook 
# !pwd
# Out:
# /Users/Daniel/Documents/Research Projects/Gotham_Web/COMMONS/Tutorials

# %%
# List of files in parent folder; ie. the one above the one we are in (we are currently in 'Tutorials', so this command lists all files in 'COMMONS')
# !ls ..
# Out:
# Tutorials commons

# %%
# The data we want to use is in INTRO_PYTHON/sample_data and it is called 'GAMA_sample1.csv
# !ls ../../INTRO_PYTHON/sample_data
# Out:
# GAMA_sample1.csv

# %%
# Import data 
path = '../../INTRO_PYTHON/sample_data/GAMA_sample1.csv' # .. tells your computer to move working directory "up" to parent (GAMA) and then change directories into everything following the slash / 
gama = pd.read_csv(path) 
gama
# Out:
#          CATAID         RA      DEC  CATAID.1        Z  nQ  SURVEY_CODE  \
# 0          6802  174.00600  0.72093      6802  0.05054   4            5
# 1          6806  174.02279  0.70594      6806  0.33124   4            5
# 2          6808  174.10071  0.65891      6808  0.22936   4            5
# 3          6810  174.10908  0.80390      6810  0.32630   4            5
# 4          6816  174.01896  0.66580      6816  0.07641   4            5
# ...         ...        ...      ...       ...      ...  ..          ...
# 113153  4321789  219.54175  1.20398   4321789  0.29884   4            5
# 113154  4322179  220.18208  1.03991   4322179  0.22929   3            5
# 113155  4327264  215.73183  1.66110   4327264  0.00006   4            5
# 113156  4327642  222.77558  1.53559   4327642  0.00034   4            5
# 113157  4348349  180.76758 -0.12518   4348349  0.12256   4            5
#
#          Z_TONRY   logmstar  dellogmstar
# 0       0.051814   9.076030     0.131666
# ...

# %%
# You can also import the data by explicitly typing your path 
my_path = '/Users/Daniel/Documents/Research Projects/Gotham_Web/OBSERVATIONS/GAMA/GAMA_Galaxies/GAMA_sample1.csv'
pd.read_csv(my_path) # Note that you will need to change this path to your working path, notably everything before '/Gotham_Web'
# Out:
#          CATAID         RA      DEC  CATAID.1        Z  nQ  SURVEY_CODE  \
# 0          6802  174.00600  0.72093      6802  0.05054   4            5
# 1          6806  174.02279  0.70594      6806  0.33124   4            5
# 2          6808  174.10071  0.65891      6808  0.22936   4            5
# 3          6810  174.10908  0.80390      6810  0.32630   4            5
# 4          6816  174.01896  0.66580      6816  0.07641   4            5
# ...         ...        ...      ...       ...      ...  ..          ...
# 113153  4321789  219.54175  1.20398   4321789  0.29884   4            5
# 113154  4322179  220.18208  1.03991   4322179  0.22929   3            5
# 113155  4327264  215.73183  1.66110   4327264  0.00006   4            5
# 113156  4327642  222.77558  1.53559   4327642  0.00034   4            5
# 113157  4348349  180.76758 -0.12518   4348349  0.12256   4            5
#
#          Z_TONRY   logmstar  dellogmstar
# 0       0.051814   9.076030     0.131666
# ...

# %%
# Path to 'observations' package which contains list of useful functions
# !ls ../../observations
# Out:
#  __init__.py      __pycache__       gama_functions.py

# %%
# !ls ../gama
# Out:
#  __init__.py      gama_functions.py

# %%
import sys  
path_to_package = '../../observations/' # changes directory to package with functions
sys.path.insert(0, path_to_package)

import gama_functions as gama_funct # we can now use functions from this file without having to expicitly code them within the notebook

# %%
import sys  
path_to_package = '../gama' # changes directory to package with functions
sys.path.insert(0, path_to_package)

import gama_functions as gama_funct # we can now use functions from this file without having to expicitly code them within the notebook

# %%
help(gama_funct)
# Out:
# Help on module gama_functions:
#
# NAME
#     gama_functions
#
# DESCRIPTION
#     Python file containing list of useful functions for working with GAMA data.
#     Meant to be imported with GAMA Tutorial notebooks.
#
# FUNCTIONS
#     Euclidean_Coordinates(RA, DEC, Z)
#         Converts spherical coordinates RA, DEC, and Z to cartesian (x, y, z) coordinates.
#
#         Parameters:
#         RA (float): Right Ascension.
#         DEC (float): Declination.
#         Z (float): Redshift.
#
#         Returns:
#         numpy.ndarray: An array containing the x, y, and z coordinates of the point.
#
# FILE
#     /Users/Daniel/Documents/Research Projects/Gotham_Web/OBSERVATIONS/GAMA/gama/gama_functions.py

# %%
gama
# Out:
#          CATAID         RA      DEC  CATAID.1        Z  nQ  SURVEY_CODE  \
# 0          6802  174.00600  0.72093      6802  0.05054   4            5
# 1          6806  174.02279  0.70594      6806  0.33124   4            5
# 2          6808  174.10071  0.65891      6808  0.22936   4            5
# 3          6810  174.10908  0.80390      6810  0.32630   4            5
# 4          6816  174.01896  0.66580      6816  0.07641   4            5
# ...         ...        ...      ...       ...      ...  ..          ...
# 113153  4321789  219.54175  1.20398   4321789  0.29884   4            5
# 113154  4322179  220.18208  1.03991   4322179  0.22929   3            5
# 113155  4327264  215.73183  1.66110   4327264  0.00006   4            5
# 113156  4327642  222.77558  1.53559   4327642  0.00034   4            5
# 113157  4348349  180.76758 -0.12518   4348349  0.12256   4            5
#
#          Z_TONRY   logmstar  dellogmstar
# 0       0.051814   9.076030     0.131666
# ...

# %%
# Get RA, DEC, and Z from GAMA dataframe
RA = gama['RA']
DEC = gama['DEC']
Z = gama['Z']
normalized_mass = gama['logmstar'] / np.linalg.norm(gama['logmstar'])

# %%
# Plot this data first to see what it looks like
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, projection='3d')
ax.set_title('Galaxies from GAMA DR3')
ax.scatter(RA, DEC, Z,s = normalized_mass*10)
plt.show()
# Out:
# /Users/Daniel/anaconda3/envs/myenv/lib/python3.11/site-packages/matplotlib/collections.py:963: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
# we can now use function from file directly
x,y,z = gama_funct.Euclidean_Coordinates(RA=RA, DEC=DEC, Z=Z)

# %%
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, projection='3d')
ax.set_title('Galaxies from GAMA DR3')
ax.scatter(x,y,z, s = normalized_mass*10)
plt.show()

# %%
# Look at 2D slice 
plt.scatter(y,x ,s = normalized_mass)
plt.gca().invert_yaxis() # need this to print right side up

# %%
# To show what defining the function looks like in the file: 
def Euclidean_Coordinates(RA, DEC, Z):
    '''
    Converts spherical coordinates RA, DEC, and Z to cartesian (x, y, z) coordinates.

    Parameters: 
    RA (float): Right Ascension.
    DEC (float): Declination.
    Z (float): Redshift.

    Returns: 
    numpy.ndarray: An array containing the x, y, and z coordinates of the point.
    '''
    H_0 = 67.8 # Hubble constant, km/s/Mpc
    c = 2.99792458e+5 # speed of light,  km/s 

    numerator = ((1+Z)**2)-1
    denominator = ((1+Z)**2)+1
    H = c/H_0
    radius = (numerator/denominator)*H    # gives radius

    for i in Z:
        d = radius
    
    RArad = RA * (np.pi/180)     # converts RA and DEC into radians 
    DECrad = DEC * (np.pi/180)

    cos = np.cos      # slightly easier than typing "np.cos" everytime
    sin = np.sin

    x = d*cos(RArad)*cos(DECrad)
    y = d*sin(RArad)*cos(DECrad)
    z = d*sin(DECrad)
    return x, y, z

# %%
# By defining the function within the notebook, we no longer have to use "gama_funct.function" to use function of interest
# we can now use function from file directly
x2, y2, z2 = Euclidean_Coordinates(RA=RA, DEC=DEC, Z=Z)

fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, projection='3d')
ax.set_title('Galaxies from GAMA DR3')
ax.scatter(x2,y2,z2, s = normalized_mass*10)
plt.show()
# Out:
# /Users/Daniel/anaconda3/envs/myenv/lib/python3.11/site-packages/matplotlib/collections.py:963: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
