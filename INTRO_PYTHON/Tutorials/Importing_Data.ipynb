# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# #### To begin, it helps to locate the **working directory** - the folder/directory you are currently working in (where this file is being run)

# %%
# Print Working Directory - gives you the folder/directory you are currently "in" while using this notebook 
# running "!" before a command in Jupyter notebook tells the jupyter cell to run as if it were being typed into a terminal
# !pwd
# Out:
# /Users/Daniel/Documents/Research Projects/Gotham_Web/INTRO_TO_PYTHON/Tutorials

# %% [markdown]
# Above, you should see the entire path to where this notebook exists on your machine.
#
# The first part should be highly individualized and specific for each person, but it should end the same:
#
# /Gotham_Web/INTRO_TO_PYTHON/Tutorials

# %%
# List of files in parent folder; ie. the one above the one we are in (we are currently in 'Tutorials', so this command lists all files in 'GAMA')
# !ls ..
# Out:
# Tutorials    intro_python sample_data

# %%
# We want to access the data in sample_data -> going "up" and then "into" the sample_data folder
# !ls ../sample_data
# Out:
# GAMA_sample1.csv

# %%
# As an example of chaning directories, we can go "up" multiple layers of data 
# !ls ../..
# Out:
# COMMONS      INTRO_PYTHON OBSERVATIONS STATISTICS
# FILAMENTS    ML           SIMULATIONS  STRUCTURE.md

# %%
# And then redirect into another directory - shows all folders in the STATISTICS sub directory
# !ls ../../STATISTICS/
# Out:
# Tutorials  statistics

# %%
# Import data 
path = '../sample_data/GAMA_sample1.csv' # .. tells your computer to move working directory "up" to parent (GAMA) and then change directories into everything following the slash / 
 # Pandas allows you to important different kinds of files into a DataFrame - a 2D structure that is vectorized (built on Numpy) to make visualizing your data easier
my_data = pd.read_csv(path)    
my_data
# Out:
#          CATAID         RA      DEC  CATAID.1        Z  nQ  SURVEY_CODE  \
# 0          6802  174.00600  0.72093      6802  0.05054   4            5
# 1          6806  174.02279  0.70594      6806  0.33124   4            5
# 2          6808  174.10071  0.65891      6808  0.22936   4            5
# 3          6810  174.10908  0.80390      6810  0.32630   4            5
# 4          6816  174.01896  0.66580      6816  0.07641   4            5
# ...         ...        ...      ...       ...      ...  ..          ...
# 113153  4321789  219.54175  1.20398   4321789  0.29884   4            5
# 113154  4322179  220.18208  1.03991   4322179  0.22929   3            5
# 113155  4327264  215.73183  1.66110   4327264  0.00006   4            5
# 113156  4327642  222.77558  1.53559   4327642  0.00034   4            5
# 113157  4348349  180.76758 -0.12518   4348349  0.12256   4            5
#
#          Z_TONRY   logmstar  dellogmstar
# 0       0.051814   9.076030     0.131666
# ...

# %%
# Alternatively you can also import the data by explicitly typing your path 
my_path = '/Users/Daniel/Documents/Research Projects/Gotham_Web/INTRO_PYTHON/sample_data/GAMA_sample1.csv'
pd.read_csv(my_path) # Note that you will need to change this path to your working path, notably everything before '/Gotham_Web'
# Out:
#          CATAID         RA      DEC  CATAID.1        Z  nQ  SURVEY_CODE  \
# 0          6802  174.00600  0.72093      6802  0.05054   4            5
# 1          6806  174.02279  0.70594      6806  0.33124   4            5
# 2          6808  174.10071  0.65891      6808  0.22936   4            5
# 3          6810  174.10908  0.80390      6810  0.32630   4            5
# 4          6816  174.01896  0.66580      6816  0.07641   4            5
# ...         ...        ...      ...       ...      ...  ..          ...
# 113153  4321789  219.54175  1.20398   4321789  0.29884   4            5
# 113154  4322179  220.18208  1.03991   4322179  0.22929   3            5
# 113155  4327264  215.73183  1.66110   4327264  0.00006   4            5
# 113156  4327642  222.77558  1.53559   4327642  0.00034   4            5
# 113157  4348349  180.76758 -0.12518   4348349  0.12256   4            5
#
#          Z_TONRY   logmstar  dellogmstar
# 0       0.051814   9.076030     0.131666
# ...
