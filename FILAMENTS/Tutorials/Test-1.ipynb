# %%
# Test to see if functions work well how they currently are (28 June 2024)
import sys 

path = '../filaments/'
sys.path.insert(0, path)
import filament_functions as fils

# %%
help(fils.import_filaments)
# Out:
# Help on function import_filaments in module filament_functions:
#
# import_filaments(path_to_filament_NDskl)
#     Imports filaments and creates dictionary containing filament coordinates and metrics
#     based on a given path to filament skeleton file.
#
#     Parameters:
#     path_to_filament_NDskl: Path fo file containing filament skeleton (.NDskl file)
#
#     Returns:
#     filament_dm_dict (dict): Dictionary of filaments containing coordinates and other filament metrics obtained from DisPerSE.

# %%
# Sample path to GAMA filaments 
path_to_skel = '../Sample_Filaments/GAMA_tess.NDnet_s5.up.NDskl.S002.BRK.ASMB.rmO.rmB.a.NDskl'

# %%
fils.import_filaments(path_to_skel)
# Out:
# header1, ANDSKEL
#
# ndims, 3
#
# Comments, #No comments (RB) (RB) (RB) (RB) (RB)
#
# Bounding box, BBOX [-1436.7,-987.426,-78.1993] [1440.62,2098.18,156.865]
#
# ncrit, 3588
# nfils, 3679
# Reading data fields:
# CP field: persistence_ratio
#
# CP field: persistence_nsigmas
#
# CP field: persistence
#
# CP field: robustness_ratio
#
# CP field: robustness
#
# CP field: persistence_pair
#
# CP field: parent_index
#
# CP field: parent_log_index
#
# CP field: log_field_value
#
# CP field: field_value
#
# CP field: cell
#
# Filament field: field_value
#
# Filament field: orientation
#
# Filament field: cell
#
# Filament field: log_field_value
#
# Filament field: type
#
# Filament field: robustness
#
# Filament field: robustness_ratio
#
# Reading filaments took 0.04 secs.
# {'ncrit': 3588,
#  'critical_points': [{'cp_idx': 2.0,
#    'px': -218.108,
#    'py': -153.104,
#    'pz': 5.52731,
#    'pair_ID': 494.0,
#    'boundary': 0.0,
#    'nfil': 2,
#    'destID,filID': [[1, 0], [2, 1]],
# ...
